# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
df = pd.read_csv("data/preprocessed.csv")
df["d"] = df["d"].apply(lambda x: x[:10])
df["y"] = df["d"].apply(lambda x: x[:4])

# %%
speakers = ['craig wright',
            'jamie dimon', 
            'vitalik buterin',
            'tyler winklevoss',
            'mark karpeles',
            'andreas antonopoulos']

d2o = df[["d", "o"]].to_dict()
d2o = {d2o["d"][i]: d2o["o"][i] for i in d2o["o"]}
d2o = dict(sorted(d2o.items(), key=lambda item: item[0]))
total = 0
for d_, o_ in d2o.items():
    d2o[d_] = d2o[d_] + total
    total = d2o[d_]

df = df[df.apply(lambda x: x['s'] in speakers, axis=1)]

speaker2o = df.groupby("s")["o"].apply(lambda x: list(x)).to_dict()
speaker2d = df.groupby("s")["d"].apply(lambda x: list(x)).to_dict()

speaker2pairs = {}
for speaker in speaker2o:
    if speaker in speakers:
        o, d = speaker2o[speaker], speaker2d[speaker]
        a, b = list(zip(*sorted(list(zip(d, o)), key=lambda x: x[0])))
        speaker2pairs[speaker] = (a, np.cumsum(b) / np.array([d2o[d_] for d_ in a]))

fig = go.Figure()
df_ = {}
for speaker, pair in speaker2pairs.items():
    df_[speaker] = pd.DataFrame(pair).T.rename(columns={0: "date", 1: "o"})
    fig.add_trace(go.Scatter(x=df_[speaker]["date"], y=df_[speaker]["o"], name=speaker))
    
    
fig.update_layout(title="Accumulated quotation share by selected speakers")
fig.update_xaxes(title="Date")
fig.update_yaxes(title="Accumulated quotation share")

fig.write_html('docs/_includes/accumulated_quotation_share_by_speaker.html')

fig.show()
# Out:
# <div>                            <div id="61d67413-69da-4876-9e5e-64ced9edfe6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61d67413-69da-4876-9e5e-64ced9edfe6f")) {                    Plotly.newPlot(                        "61d67413-69da-4876-9e5e-64ced9edfe6f",                        [{"name":"andreas antonopoulos","type":"scatter","x":["2013-06-07","2013-11-03","2013-12-18","2013-12-18","2014-01-23","2014-02-07","2014-02-09","2014-02-10","2014-02-10","2014-02-11","2014-02-11","2014-02-11","2014-02-11","2014-02-13","2014-02-16","2014-02-26","2014-03-01","2014-03-10","2014-03-20","2014-04-02","2014-04-11","2014-04-25","2014-04-25","2014-06-05","2014-06-11","2014-08-05","2014-08-05","2014-09-16","2014-09-16","2014-11-24","2014-11-25","2014-11-26","2014-12-03","2015-01-14","2015-01-22","2015-01-28","2015-01-28","2015-03-12","2015-03-12","2015-03-24","2015-03-24","2015-07-16","2015-08-11","2015-11-02","2015-11-02","2015-12-20","2016-04-19","2016-05-03","2016-05-18","2016-05-18","2016-05-18","2016-05-18","2016-08-03","2016-08-03","2016-08-03","2016-08-03","2016-08-03","2016-08-10","2016-08-24","2016-12-08","2016-12-22","2016-12-22","2016-12-22","2016-12-29","2017-03-06","2017-03-08","2017-03-12","2017-03-23","2017-04-01","2017-05-08","2017-05-08","2017-05-08","2017-05-08","2017-05-15","2017-05-15","2017-06-21","2017-06-28","2017-06-28","2017-07-05","2017-07-06","2017-07-07","2017-07-22","2017-08-02","2017-08-16","2017-08-22","2017-09-05","2017-09-08","2017-09-20","2017-10-19","2017-10-19","2017-10-20","2017-10-22","2017-11-05","2017-11-12","2017-11-18","2017-11-26","2017-11-26","2017-11-28","2017-11-30","2017-12-09","2017-12-15","2017-12-15","2017-12-15","2017-12-21","2017-12-21","2017-12-21","2017-12-21","2017-12-23"],"y":[0.0017825311942959,0.023445463812436288,0.022284122562674095,0.02321262766945218,0.02164862614487927,0.024630541871921183,0.02540983606557377,0.02616516762060507,0.02698282910874898,0.029411764705882353,0.03022875816993464,0.03104575163398693,0.031862745098039214,0.032599837000814993,0.03322528363047002,0.03278688524590164,0.03333333333333333,0.033690658499234305,0.03294289897510981,0.03460706560922855,0.03495007132667618,0.03672316384180791,0.03742937853107345,0.038995373430270985,0.04018445322793149,0.037874160048869884,0.03909590714722053,0.039262343842950624,0.04045211183819155,0.037438958220293,0.03796095444685466,0.04008667388949079,0.04097035040431267,0.03979328165374677,0.04014410705095214,0.04028556858745538,0.0407955124936257,0.0405,0.041,0.04119106699751861,0.04168734491315137,0.03893724232707284,0.0383586083853702,0.03423848878394333,0.03463203463203463,0.035303146584804296,0.035593855376545525,0.035437430786267994,0.03491720662347012,0.035277177825773935,0.035637149028077755,0.03599712023038157,0.03487569060773481,0.03522099447513812,0.035566298342541436,0.03591160220994475,0.036256906077348064,0.03650137741046832,0.03731598767545361,0.03617231173955936,0.03622715404699739,0.03655352480417755,0.0368798955613577,0.03714565004887586,0.0364732001268633,0.036755386565272496,0.037037037037037035,0.037177063642092,0.03732747804265998,0.03677597303095311,0.03708243947287772,0.03800183879865155,0.03830830524057616,0.03792176769184831,0.038518960883845925,0.03760485970494649,0.03798561151079137,0.03856115107913669,0.03964378052283826,0.03991958644457209,0.04011461318051576,0.04080476055539813,0.04090267983074753,0.04100418410041841,0.04114539894356408,0.04111479028697572,0.04131093362709997,0.04079978384220481,0.03998947645356485,0.04025256511444357,0.04072517078297425,0.04096638655462185,0.040992167101827674,0.041341653666146644,0.041173443129181676,0.041271468854139966,0.04178415790822866,0.042008196721311473,0.042231891476836446,0.04148962759310172,0.04147007698038 ...

# %%
df = pd.read_csv("data/preprocessed.csv")
df["d"] = df["d"].apply(lambda x: x[:10])
df["y"] = df["d"].apply(lambda x: x[:4])

# %%
occ2o = df.groupby("occupation")["o"].apply(lambda x: list(x)).to_dict()
occ2d = df.groupby("occupation")["d"].apply(lambda x: list(x)).to_dict()
d2o = df[["d", "o"]].to_dict()

# %%
d2o = {d2o["d"][i]: d2o["o"][i] for i in d2o["o"]}

# %%
total = 0 
d2o = dict(sorted(d2o.items(), key=lambda item: item[0]))
for d_, o_ in d2o.items():
    d2o[d_] = d2o[d_] + total
    total = d2o[d_]

# %%
occ2total = {occ: sum(o_) for occ, o_ in occ2o.items()}
best_occs = sorted(occ2total.items(), key=lambda item: item[1])
best_occs = [occ for occ, _ in best_occs[-5:]]

# %%
occ2pairs = {}
all_dates = []
for occ in occ2o:
    if occ in best_occs:
        o, d = occ2o[occ], occ2d[occ]
        a, b = list(zip(*sorted(list(zip(d, o)), key=lambda x: x[0])))
        occ2pairs[occ] = (a, np.cumsum(b))
        all_dates += a

# %%
fig = go.Figure()
df = {}
for occ, pair in occ2pairs.items():
    df[occ] = pd.DataFrame(pair).T.rename(columns={0: "date", 1: "o"})
    fig.add_trace(go.Scatter(x=df[occ]["date"], y=df[occ]["o"], name=occ))

fig.show()
# Out:
# <div>                            <div id="77f0673e-35be-4fef-9c8b-dd3c4bcfe835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("