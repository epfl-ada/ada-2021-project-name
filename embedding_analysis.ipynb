# %%
import pickle
import numpy as np
import pandas as pd
import plotly.express as ex
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("data/preprocessed.csv")
df
# Out:
#                                                       q                    d  \
# 0     even quantum cryptography does not solve all o...  2008-10-18 02:33:56
# 1     this is good work great cryptography i love th...  2008-12-30 22:21:35
# 2     people can foresee the future only when it coi...  2008-11-04 05:14:51
# 3     the mathematics of ciphers number theory  rsa ...  2008-11-21 08:38:20
# 4     can disarm the normal interest groups and othe...  2008-11-06 06:51:34
# ...                                                 ...                  ...
# 7806  one of the main problems with bitcoin is that ...  2017-11-13 11:51:41
# 7807  the only way it has value is if the next guy i...  2017-11-27 09:42:09
# 7808  we are expanding our blockchain teams across e...  2017-11-15 22:00:00
# 7809  cryptocurrencies are in an exponential bubble ...  2017-12-28 12:12:00
# 7810  its a snowball effect thats happening on bitco...  2017-11-27 13:02:50
#
#                    s   o gender                      birth     occupation
# 0     bruce schneier   1   male  ['+1963-01-15T00:00:00Z']  cryptographer
# 1     bruce schneier   2   male  ['+1963-01-15T00:00:00Z']  cryptographer
# 2      george orwell   6   male                     [None]            NaN
# 3     bruce schneier   1   male  ['+1963-01-15T00:00:00Z']  cryptographer
# 4       barack obama   4   male  ['+1961-08-04T00:00:00Z']     politician
# ...              ...  ..    ...                        ...            ...
# 7806   hussein sayed  31   male  ['+1991-09-18T00:00:00Z']       investor
# 7807     neil wilson   7   male             ['1978-06-26']            ceo
# 7808      paul brody   3   male  ['+1961-01-01T00:00:00Z']      trumpeter
# 7809        ron paul   1   male  ['+1935-08-20T00:00:00Z']     politician
# 7810    james hughes   1   male             ['1961-05-27']    sociologist
#
# [7811 rows x 7 columns]

# %%
with open("data/embeds.pkl", "rb") as f:
    embeds = pickle.load(f)
embeds.shape
# Out:
# (7811, 384)

# %%
def get_emb(x):
    return embeds[x.name]

df["embd"] = df.apply(lambda x: get_emb(x), axis=1)
df["occupation"] = df["occupation"].fillna('None')
df
# Out:
#                                                       q                    d  \
# 0     even quantum cryptography does not solve all o...  2008-10-18 02:33:56
# 1     this is good work great cryptography i love th...  2008-12-30 22:21:35
# 2     people can foresee the future only when it coi...  2008-11-04 05:14:51
# 3     the mathematics of ciphers number theory  rsa ...  2008-11-21 08:38:20
# 4     can disarm the normal interest groups and othe...  2008-11-06 06:51:34
# ...                                                 ...                  ...
# 7806  one of the main problems with bitcoin is that ...  2017-11-13 11:51:41
# 7807  the only way it has value is if the next guy i...  2017-11-27 09:42:09
# 7808  we are expanding our blockchain teams across e...  2017-11-15 22:00:00
# 7809  cryptocurrencies are in an exponential bubble ...  2017-12-28 12:12:00
# 7810  its a snowball effect thats happening on bitco...  2017-11-27 13:02:50
#
#                    s   o gender                      birth     occupation  \
# 0     bruce schneier   1   male  ['+1963-01-15T00:00:00Z']  cryptographer
# 1     bruce schneier   2   male  ['+1963-01-15T00:00:00Z']  cryptographer
# 2      george orwell   6   male                     [None]           None
# 3     bruce schneier   1   male  ['+1963-01-15T00:00:00Z']  cryptographer
# 4       barack obama   4   male  ['+1961-08-04T00:00:00Z']     politician
# ...              ...  ..    ...                        ...            ...
# 7806   hussein sayed  31   male  ['+1991-09-18T00:00:00Z']       investor
# 7807     neil wilson   7   male             ['1978-06-26']            ceo
# 7808      paul brody   3   male  ['+1961-01-01T00:00:00Z']      trumpeter
# 7809        ron paul   1   male  ['+1935-08-20T00:00:00Z']     politician
# 7810    james hughes   1   male             ['1961-05-27']    sociologist
#
#                                                    embd
# 0     [-0.043082796, -0.018537337, -0.031235695, 0.0...
# 1     [-0.062056527, 0.047530353, -0.102777876, -0.0...
# 2     [0.007510899, 0.027965602, 0.0928818, 0.030693...
# 3     [-0.06203978, 0.05027579, -0.06726297, 0.01422...
# 4     [-0.022280598, 0.03585137, 0.029202083, 0.0018...
# ...                                                 ...
# 7806  [0.023816716, 0.0022417386, -0.04340269, -0.02...
# 7807  [-0.006214832, 0.0041340687, -0.05988493, -0.0...
# 7808  [0.032797523, -0.062365446, -0.025915723, -0.0...
# 7809  [-0.01813105, -0.016683614, -0.05587506, 0.031...
# 7810  [-0.0057961536, -0.054411568, -0.00020769305, ...
#
# [7811 rows x 8 columns]

# %%
embeddings = embeds
# standartized_embeddings = (embeddings - embeddings.mean()) / embeddings.std()
components = PCA(n_components=2).fit_transform(embeddings)

components.shape
# Out:
# (7811, 2)

# %%
ex.scatter(components[:, 0], components[:, 1], color=df.occupation)
# Out:
# <div>                            <div id="eb6b9c84-151c-4a0e-a3e4-e959756f1d2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb6b9c84-151c-4a0e-a3e4-e959756f1d2c")) {                    Plotly.newPlot(                        "eb6b9c84-151c-4a0e-a3e4-e959756f1d2c",                        [{"hovertemplate":"color=cryptographer<br>x=%{x}<br>index=%{y}<extra></extra>","legendgroup":"cryptographer","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"cryptographer","showlegend":true,"type":"scattergl","x":[0.42963162064552307,0.3941119313240051,0.4550850987434387,0.21598823368549347,0.3580915629863739,0.19909505546092987,0.2391042560338974,0.30802589654922485,0.5587201118469238,0.4154109060764313,0.44240546226501465,0.4048110246658325,0.40579885244369507,0.32819032669067383,0.42662933468818665,0.3274706304073334,0.4023798406124115,0.4754805266857147,0.4566378593444824,0.37123221158981323,0.4080445468425751,0.3437659740447998,0.128957599401474,0.4603433609008789,0.3526008427143097,0.5307873487472534,0.3720186650753021,0.2998102009296417,0.36971819400787354,0.03194265812635422,0.15576617419719696,0.3401966989040375,0.48238080739974976,0.3190533518791199,0.3027988076210022,0.5058367252349854,0.34035980701446533,0.3711482584476471,0.19943569600582123,0.3171549141407013,0.3892606794834137,0.5366644263267517,0.39296650886535645,0.35369813442230225,0.4023333489894867,0.37552598118782043,0.31639787554740906,0.4132814407348633,0.2785347104072571,0.29085466265678406,0.4415334165096283,0.46568000316619873,0.390241414308548,0.3773316442966461,0.2783343493938446,0.3149673342704773,0.3788025379180908,0.39724767208099365,0.3701736629009247,0.21082596480846405,0.5380174517631531,0.2993501126766205,0.45470425486564636,0.3040214776992798,0.2665371298789978,0.3201499879360199,0.1661834418773651,0.17097581923007965,0.36773836612701416,0.4154365360736847,0.38929376006126404,0.4116506576538086,0.22494730353355408,0.3891139030456543,0.3010713458061218,0.44012677669525146,0.22882062196731567,0.4169454574584961,0.3150518238544464,0.3183145821094513,0.397549033164978,0.37333884835243225,0.3882507085800171,0.42238354682922363,0.43545103073120117,0.4115763306617737,0.30786094069480896,0.4054945707321167,0.4282298982143402,0.2600812315940857,0.21937870979309082,0.15718746185302734,0.39030447602272034,0.24632997810840607,0.34074148535728455,0.33936479687690735,0.08196927607059479,0.39876189827919006,0.28307726979255676,0.28327134251594543,0.29504263401031494,0.43984976410865784,0.450565367937088,0.40438446402549744,0.3813992142677307,0.29871708154678345,0.35370689630508423,0.2999512553215027,0.42317304015159607,0.28955137729644775,0.37505820393
337890625,54.92636489868164,43.396358489990234,42.41866683959961,53.97834396362305,54.16569900512695,52.54016876220703,58.936363220214844,46.561058044433594,55.72151184082031,52.643367767333984,44.89467239379883,57.30713653564453,-15.165143966674805,52.70480728149414,-15.46152400970459,52.16965866088867,45.470924377441406,57.04867935180664,54.722572326660156,51.49228286743164,45.906715393066406,60.622154235839844,51.69636535644531,63.316505432128906,-5.427804946899414,58.73320007324219,56.53389358520508,52.226600646972656,-5.414899826049805,53.19330978393555,63.113285064697266,-21.331340789794922,-5.403731822967529,41.70982360839844,42.371768951416016,-37.431846618652344,48.01611328125,-5.411036491394043,-73.95661163330078,1.037839412689209,41.3263053894043,60.71943664550781,46.7309684753418,69.16107177734375,44.72385025024414,51.82759094238281,6.271726131439209,60.6991081237793,41.12612533569336,63.312191009521484,47.61857604980469,60.803653717041016,42.96670913696289,49.657562255859375,49.59837341308594,44.09025192260742,42.24880599975586,-13.506217002868652,34.5759162902832,57.35942840576172,-17.670045852661133,34.47316360473633,60.8314208984375,51.93584060668945,49.86357116699219,49.17279815673828,-29.682592391967773,41.013031005859375,60.70191192626953,58.5007209777832,8.948236465454102,-16.40643310546875,69.9906234741211,58.37964630126953,52.680545806884766,45.18780517578125,59.067203521728516,58.07294845581055,68.620765686035 ...

# %% [markdown]
# ---

# %% [markdown]
# Maybe we will see something better if we leave only top 10 of the most popular ocupations

# %%
N_OCCUPATIONS = 5
occupations_top_n = df.groupby('occupation').sum().sort_values('o', ascending=False).index[:N_OCCUPATIONS]
occupations_top_n
# Out:
# Index(['economist', 'businessperson', 'entrepreneur', 'scientist', 'director'], dtype='object', name='occupation')

# %%
df_occupations_top_n = df[df.occupation.apply(lambda x: x in occupations_top_n)]
df_occupations_top_n.head()
# Out:
#                                                     q                    d  \
# 7   cryptography has become an important part of o...  2008-10-15 18:41:21
# 9   cryptography has become an important part of o...  2008-10-14 16:28:43
# 11  we will be using strong authentication methods...  2008-10-27 16:05:08
# 21  one of big hurdles is that this is something y...  2009-07-06 23:50:49
# 23  so why hasnt the nobel foundation bowed to fem...  2009-10-08 06:03:47
#
#                 s  o gender                      birth occupation  \
# 7   richard brown  1   male             ['1916-01-01']   director
# 9   richard brown  1   male             ['1916-01-01']   director
# 11      vint cerf  1   male  ['+1943-06-23T00:00:00Z']  scientist
# 21   dan kaminsky  2   male  ['+1979-00-00T00:00:00Z']  scientist
# 23  larry summers  1   male  ['+1954-11-30T00:00:00Z']  economist
#
#                                                  embd
# 7   [0.015955096, 0.05288954, -0.034609336, -0.100...
# 9   [-0.003245669, 0.022950932, -0.047379404, -0.0...
# 11  [-0.08502854, 0.062946305, -0.038307853, -0.05...
# 21  [-0.01391253, 0.011913197, -0.11620632, -0.003...
# 23  [0.018347966, -0.032968037, -0.013841194, 0.08...

# %%
embeddings_occupations_top_n = np.array([e for e in df_occupations_top_n.embd.values])
embeddings_occupations_top_n.shape
# Out:
# (3205, 384)

# %%
components_tsne = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(embeddings_occupations_top_n)
components_tsne.shape
# Out:
# (3205, 2)

# %%
ex.scatter(components_tsne[:, 0], components_tsne[:, 1], color=df_occupations_top_n.occupation)
# Out:
# <div>                            <div id="e8866c44-5fd6-4ca3-bec1-71af9b438e2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e